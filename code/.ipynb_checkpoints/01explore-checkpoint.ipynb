# %% [markdown]
# ## Exploratory Data Analysis I
#
# Let's begin our analysis by exploring both the univariate and bivariate characteristics of this dataset. The general goals of this step include:
#
# * finding outliers & distributions through univariate visualizations
# * finding trends & patterns through bivariate visualizations
#
# When you are done with this section of the project, validate that your output matches the screenshot provided in the `docs/part1.md` file and answer the questions located underneath `Exploratory Data Analysis II` in your own words.

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load `data/raw/shopping.csv` as a pandas dataframe
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

df = pd.read_csv("../data/raw/shopping.csv")

# %%
# print out the first 5 rows for display
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html

df.head()
# Out:
#    Customer ID   Age  Gender Item Purchased  Purchase Amount (USD)  Location  \
# 0         3475   NaN    Male         Jacket              30.904467     Maine
# 1         3698  21.0  Female       Backpack              31.588259       NaN
# 2         2756  31.0    Male       Leggings              24.231704    Nevada
# 3         3340   NaN    Male        Pajamas              33.918834  Nebraska
# 4         3391  38.0    Male     Sunglasses              36.545487    Oregon
#
#   Size         Color  Season  Review Rating Shipping Type Promo Code Used  \
# 0    M  Burnt orange    Fall            4.0      Standard              No
# 1    L     Turquoise  Winter            2.0       Express              No
# 2    M   Terra cotta  Winter            4.0      Standard              No
# 3    M         Black  Winter            NaN      Standard              No
# 4    S     Aubergine  Summer            NaN      Standard              No
#
#    Previous Purchases Payment Method Frequency of Purchases
# 0                   0    Credit Card                    NaN
# 1                   1    Credit Card                Monthly
# 2                   0    Credit Card                    NaN
# 3                   2    Credit Card              Bi-Weekly
# 4                   0    Credit Card                    NaN

# %%
# Print out summary statistics for all numeric columns
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html

df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3510.000000            3900.000000    1431.000000
# mean   1950.500000    34.256695              38.708329       3.904962
# std    1125.977353    10.616340              11.504923       1.105952
# min       1.000000    18.000000              11.392520       1.000000
# 25%     975.750000    26.000000              29.332617       4.000000
# 50%    1950.500000    33.000000              36.953004       4.000000
# 75%    2925.250000    41.000000              48.739596       5.000000
# max    3900.000000    75.000000              69.567481       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean             5.841538
# std              5.843695
# min              0.000000
# 25%              1.000000
# 50%              4.000000
# 75%              9.000000
# max             20.000000

# %% [markdown]
# ## Univariate Analysis
#
# Let's generate visualizatons for each numeric variable to get an idea of the outliers & distributions present in our dataset.
#
# In addition, let's also visualize the frequency-count of qualitative variables to get an understanding of the composition of our dataset.

# %%
# plot a seaborn histogram for the "Age" column
# Documentation: https://seaborn.pydata.org/generated/seaborn.histplot.html

sns.histplot(data=df, x="Age")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
# plot a seaborn histogram for the "Purchase Amount (USD)" column

sns.histplot(data=df, x="Purchase Amount (USD)")
# Out:
# <AxesSubplot:xlabel='Purchase Amount (USD)', ylabel='Count'>

# %%
# plot a seaborn histogram for the "Review Rating" column

sns.histplot(data=df, x="Review Rating")
# Out:
# <AxesSubplot:xlabel='Review Rating', ylabel='Count'>

# %%
# plot a seaborn histogram for the "Previous Purchases" column

sns.histplot(data=df, x="Previous Purchases")
# Out:
# <AxesSubplot:xlabel='Previous Purchases', ylabel='Count'>

# %%
# count the frequency of unique values in the "Gender" column, save this value into a new dataframe named "gender_counts"
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.value_counts.html

gender_counts = df["Gender"].value_counts()
gender_counts
# Out:
# Gender
# Male          1971
# Female        1894
# Non-binary      35
# Name: count, dtype: int64

# %%
# plot a matplotlib barplot for the gender_counts dataframe
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.bar.html

gender_counts.plot.bar()
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
# count the frequency of unique values in the "Season" column, save this value into a new dataframe named "season_counts"

season_counts = df['Season'].value_counts()
season_counts
# Out:
# Season
# Winter    1321
# Fall      1056
# Summer     942
# Spring     581
# Name: count, dtype: int64

# %%
# plot a matplotlib barplot for the season_counts dataframe

season_counts.plot.bar()
# Out:
# <AxesSubplot:xlabel='Season'>

# %%
# count the frequency of unique values in the "Shipping Type" column, save this value into a new dataframe named "ship_counts"

ship_counts = df['Shipping Type'].value_counts()
ship_counts
# Out:
# Shipping Type
# Standard          2162
# 2-Day Shipping    1173
# Next Day Air       284
# Express            279
# Store Pickup         2
# Name: count, dtype: int64

# %%
# plot a matplotlib barplot for the shipping_counts dataframe

ship_counts.plot.bar()
# Out:
# <AxesSubplot:xlabel='Shipping Type'>

# %%
# count the frequency of unique values in the "Promo Code Used" column, save this value into a new dataframe named "promo_counts"

promo_counts = df['Promo Code Used'].value_counts()
promo_counts
# Out:
# Promo Code Used
# No     2223
# Yes    1677
# Name: count, dtype: int64

# %%
# plot a matplotlib barplot for the promo_counts dataframe

promo_counts.plot.bar()
# Out:
# <AxesSubplot:xlabel='Promo Code Used'>

# %%
# count the frequency of unique values in the "Payment Method" column, save this value into a new dataframe named "pay_counts"

pay_counts = df['Payment Method'].value_counts()
pay_counts
# Out:
# Payment Method
# Credit Card      1400
# Debit Card       1300
# PayPal            600
# Venmo             579
# Bank Transfer      11
# Cash               10
# Name: count, dtype: int64

# %%
# plot a matplotlib barplot for the pay_counts dataframe

pay_counts.plot.bar()
# Out:
# <AxesSubplot:xlabel='Payment Method'>

# %%
# count the frequency of unique values in the "Frequency of Purchases" column, save this value into a new dataframe named "purch_counts"

purch_counts = df['Frequency of Purchases'].value_counts()
purch_counts
# Out:
# Frequency of Purchases
# Quarterly    664
# Monthly      405
# Annually     307
# Bi-Weekly    155
# Weekly        29
# Name: count, dtype: int64

# %%
# plot a matplotlib barplot for the purch_counts dataframe

purch_counts.plot.bar()
# Out:
# <AxesSubplot:xlabel='Frequency of Purchases'>

# %%
# count the frequency of unique values in the "Location" column, save this value into a new dataframe named "loc_counts"

loc_counts = df['Location'].value_counts()
loc_counts.head()
# Out:
# Location
# California    91
# Alabama       81
# Delaware      81
# Montana       80
# Nebraska      80
# Name: count, dtype: int64

# %%
# plot a horizontal barplot for the loc_counts dataframe
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.barh.html
# resize the figure using "plt.figure(figsize=(10,10))" to "unsquish" your visualization

plt.figure(figsize=(10,10))
loc_counts.plot.barh()
# Out:
# <AxesSubplot:ylabel='Location'>

# %% [markdown]
# ## Bivariate Analysis
#
# Let's generate visualizatons for relationships between multiple numeric variables to get an idea of patterns and clusters that might be present in our dataset.

# %%
# Create a boxplot that reveals the range of "Purchase Amount (USD)" for each "Gender" 
# Documentation: https://seaborn.pydata.org/generated/seaborn.boxplot.html

sns.boxplot(data=df, x="Purchase Amount (USD)", y="Gender")
# Out:
# <AxesSubplot:xlabel='Purchase Amount (USD)', ylabel='Gender'>

# %%
# Create a boxplot that reveals the range of "Purchase Amount (USD)" for each "Season" 
# Documentation: https://seaborn.pydata.org/generated/seaborn.boxplot.html

sns.boxplot(data=df, x="Purchase Amount (USD)", y="Season")
# Out:
# <AxesSubplot:xlabel='Purchase Amount (USD)', ylabel='Season'>

# %%
# Create a boxplot that reveals the range of "Purchase Amount (USD)" for each "Review Rating" 
# Documentation: https://seaborn.pydata.org/generated/seaborn.boxplot.html

sns.boxplot(x=df["Purchase Amount (USD)"], y=df["Review Rating"].astype(str))
# Out:
# <AxesSubplot:xlabel='Purchase Amount (USD)', ylabel='Review Rating'>

# %%
# Create a boxplot that reveals the range of "Purchase Amount (USD)" for each "Promo Code Used" 
# Documentation: https://seaborn.pydata.org/generated/seaborn.boxplot.html

sns.boxplot(data=df, x="Purchase Amount (USD)", y="Promo Code Used")
# Out:
# <AxesSubplot:xlabel='Purchase Amount (USD)', ylabel='Promo Code Used'>

# %%
# Create a boxplot that reveals the range of "Payment Method" for each "Purchase Amount (USD)"
# Documentation: https://seaborn.pydata.org/generated/seaborn.boxplot.html

sns.boxplot(data=df, x="Purchase Amount (USD)", y="Payment Method")
# Out:
# <AxesSubplot:xlabel='Purchase Amount (USD)', ylabel='Payment Method'>

# %%
# plot a grid of diagrams on all numeric columns where the upper-half of the grid are scatter-plots
# the bottom-half are kde-plots
# and the diagonal is a histplot
# Documentation: https://seaborn.pydata.org/tutorial/axis_grids.html
# This might take a few seconds to load
# to read the kde diagrams in the bottom-half check out https://www.greenbelly.co/pages/contour-lines

g = sns.PairGrid(df)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.histplot)

# %% [markdown]
# ## Exploratory Data Analysis II
#
# In the next section, answer a few questions regarding your dataset using the visualizations you've generated.

# %% [markdown]
# ### Q1
#
# Which state contains the most amount of shoppers? Which state contains the least?

# %% [markdown]
# The state that contains the most amount of shoppers is California while the state that contains the least amount of shoppers is Hawaii.

# %% [markdown]
# ### Q2
#
# Which season has the largest amount of purchases?

# %% [markdown]
# The season with the largest amount of purchases is Winter.

# %% [markdown]
# ### Q3
#
# What is the most popular form of payment for our customers in the US? What is the least popular form of payment?

# %% [markdown]
# The most popular form of payment for our customers in the US is the use of Credit Card and the least popular form of payment is Cash.

# %% [markdown]
# ### Q4
#
# What is the most popular form of shipping for our customers in the US? What is the least popular form of shipping?

# %% [markdown]
# The most popular form of shipping for customers in the US is standard shipping and the least popular form of shipping in the US is store pickup.

# %% [markdown]
# ### Q5
#
# What kind of distribution do we observe for our `Age` column? What does this tell us about the typical shopper in the US?

# %% [markdown]
# The distribution that is observed from our `Age` column is a skewed right distribution. This tells us that our typical shopper is around the age of 30 and less of our shoppers are on the older side.

# %% [markdown]
# ### Q6
#
# What kind of distribution do we observe for our `Purchase Amount (USD)` column? Why might this be? Take a look at the boxplots that you've generated to help answer this question.

# %% [markdown]
# The kind of distribution that is observed in the `Purchase Amount (USD)` column is a bimodal distribution meaning it has two peaks. This might be due to the fact that some transactions have a promo code applied while others do not. As we can see from the boxplot between the `Promo Code Used` column and our `Purchase Amount (USD)` column we can see that there is a difference in the distributions when there is a promo code applied and when there is not a code applied.
